# %%
from create_model import *
# %load_ext autoreload
# %autoreload 2
#importing functions from .py file
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Applying new dataset to saved model
#
# ADD MORE MARKDOWNS to explain what is happening

# %%
directory = '/Users/justycewatson/Desktop/CIERA_files/NGC6819/ngc6819_single_resfiles' 

ngc6819_statistic = create_features(directory)
# creating the data table using 'create_stats' function with the directory files
 
ngc6819_statistic

#need to send model same columns in xtest 
#convert columns from ngc6819 to np array -- send to make preds function
# Out:
#                           source_id     Width  Upper_bound  Lower_bound  \
# 0     gaia_2076279137552154112_sin2  1.611105     0.281932     0.241271
# 1     gaia_2076298933067389056_sin2  0.851659     0.281932     0.241271
# 2     gaia_2076584355102288128_sin2  1.568087     0.281932     0.241271
# 3     gaia_2076488525792609792_sin2  0.384405     0.281932     0.241271
# 4     gaia_2076581851147039232_sin2  1.684027     0.281932     0.241271
# ...                             ...       ...          ...          ...
# 1683  gaia_2076393834663325568_sin2  1.420736     0.281932     0.241271
# 1684  gaia_2076380400005524224_sin2  1.370467     0.281932     0.241271
# 1685  gaia_2076299895139969536_sin2  0.444381     0.281932     0.241271
# 1686  gaia_2076393662864610688_sin2  1.519873     0.281932     0.241271
# 1687  gaia_2076489079855047936_sin2  0.523203     0.281932     0.241271
#
#          Stdev        SnR  Dip_p  Dip_value  KS_value           KS_p  \
# 0     0.709164  12.619723    0.0   0.015125  0.162550  2.444986e-145
# 1     0.492672  18.154950    0.0   0.075300  0.253198   0.000000e+00
# 2     0.706918  12.674155    0.0   0.015795  0.165182  1.029681e-147
# 3     0.494811  18.364221    0.0   0.052020  0.280571   0.000000e+00
# 4     0.748072  11.787783    0.0   0.021270  0.181619  1.034206e-178
# ...        ...        ...    ...        ...       ...            ...
# 1683  0.685752  12.768550    0.0   0.009732  0.166534  1.423910e-152
# 1684  0.686048  12.883365    0.0   0.021400  0.142672  3.869411e-110
# 1685  0.175729  54.419198    0.0   0.085369  0.171486  1.570289e-160
# 1686  0.696125  12.398271    0.0   0.016644  0.163665  2.402290e-147
# 1687  0.225537  41.811852    0.0   0.023360  0.106827   2.570763e-62
#
#                ESS
# 0      9843.157558
# 1      9489.604553
# 2      9724.240691
# 3     10011.903693
# 4      9938.111083
# ...            ...
# 1683   9908.585561
# 1684   9793.321886
# 1685  10267.820193
# 1686   9672.877126
# 1687   9804.916131
#
# [1688 rows x 11 columns]

# %%
ngc6819_clean, ngc6819_array = prepare_df_for_model(ngc6819_statistic)
ngc6819_array
# Out:
# array([[1.61110472e+000, 2.81932000e-001, 2.41271000e-001, ...,
#         1.62549801e-001, 2.44498621e-145, 9.84315756e+003],
#        [8.51659000e-001, 2.81932000e-001, 2.41271000e-001, ...,
#         2.53198381e-001, 0.00000000e+000, 9.48960455e+003],
#        [1.56808700e+000, 2.81932000e-001, 2.41271000e-001, ...,
#         1.65182186e-001, 1.02968083e-147, 9.72424069e+003],
#        ...,
#        [4.44381000e-001, 2.81932000e-001, 2.41271000e-001, ...,
#         1.71485944e-001, 1.57028857e-160, 1.02678202e+004],
#        [1.51987300e+000, 2.81932000e-001, 2.41271000e-001, ...,
#         1.63665339e-001, 2.40228960e-147, 9.67287713e+003],
#        [5.23203000e-001, 2.81932000e-001, 2.41271000e-001, ...,
#         1.06827309e-001, 2.57076282e-062, 9.80491613e+003]])

# %%
pipe = load_model('my_model.pkl')
#reading in the saved model

y_pred_6819 = make_preds(pipe, ngc6819_array)
y_pred_6819
#predictions for 6819 from model
# Out:
# array(['Bad', 'Bad', 'Bad', ..., 'Good', 'Bad', 'Good'], dtype=object)

# %%
np.where(y_pred_6819 == 'Good')
# Out:
# (array([   8,   12,   17,   22,   28,   29,   33,   35,   37,   41,   42,
#           44,   48,   49,   55,   57,   63,   65,   66,   76,   79,   80,
#           81,   82,   85,   86,   87,   89,   90,   91,   92,   94,  101,
#          105,  116,  119,  124,  130,  132,  137,  145,  147,  162,  168,
#          170,  172,  175,  177,  180,  186,  190,  191,  201,  204,  205,
#          209,  214,  216,  225,  226,  227,  230,  232,  233,  234,  235,
#          243,  244,  248,  250,  258,  261,  264,  266,  267,  268,  281,
#          284,  285,  296,  297,  306,  313,  321,  347,  348,  351,  362,
#          363,  364,  367,  368,  377,  378,  381,  388,  390,  392,  393,
#          395,  399,  402,  408,  409,  413,  414,  418,  419,  421,  429,
#          450,  456,  476,  478,  489,  490,  500,  505,  516,  518,  529,
#          530,  531,  533,  534,  537,  538,  543,  546,  547,  553,  556,
#          560,  561,  562,  564,  573,  575,  580,  582,  583,  585,  586,
#          595,  597,  602,  610,  616,  620,  622,  633,  641,  644,  659,
#          663,  667,  668,  672,  674,  679,  680,  682,  683,  686,  692,
#          698,  705,  708,  712,  714,  716,  719,  720,  723,  728,  729,
#          732,  746,  755,  756,  758,  761,  766,  773,  780,  793,  809,
#          813,  814,  815,  818,  828,  829,  831,  834,  835,  842,  852,
#          854,  862,  863,  864,  865,  870,  872,  873,  876,  879,  880,
#          884,  901,  911,  915,  922,  923,  925,  927,  929,  936,  939,
#          944,  945,  946,  950,  958,  961,  965,  972,  973,  974,  978,
#          980,  981,  982,  983,  985,  986,  988,  996, 1004, 1006, 1010,
#         1015, 1017, 1025, 1034, 1035, 1038, 1049, 1050, 1052, 1060, 1064,
#         1071, 1074, 1076, 1079, 1087, 1103, 1104, 1109, 1110, 1111, 1113,
#         1119, 1120, 1126, 1130, 1133, 1137, 1138, 1140, 1144, 1148, 1167,
#         1175, 1186, 1187, 1190, 1192, 1204, 1208, 1213, 1215, 1218, 1221,
#         1225, 1226, 1230, 1234, 1235, 1236, 1240, 1247, 1250, 1251, 1252,
#         1254, 1256, 1268, 1271, 1272, 1273, 1274, 1284, 1285, 1295, 1296,
#         1308, 1311, 1313, 1316, 1322, 1328, 1330, 1340, 1342, 1344, 1347,
#         1349, 1351, 1354, 1355, 1369, 1387, 1389, 1392, 1394, 1395, 1403,
#         1405, 1410, 1411, 1413, 1420, 1421, 1428, 1429, 1432, 1437, 1438,
#         1441, 1442, 1446, 1450, 1454, 1456, 1457, 1458, 1460, 1462, 1464,
#         1471, 1477, 1480, 1481, 1485, 1486, 1487, 1488, 1493, 1503, 1506,
#         1517, 1523, 1528, 1529, 1536, 1539, 1541, 1542, 1545, 1546, 1549,
#         1554, 1557, 1558, 1560, 1563, 1566, 1569, 1574, 1577, 1582, 1586,
#         1604, 1606, 1608, 1612, 1615, 1630, 1635, 1636, 1642, 1644, 1650,
#         1654, 1662, 1663, 1664, 1674, 1676, 1677, 1685, 1687]),)
